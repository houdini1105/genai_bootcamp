# %%
# Challenge 1: Basic File Reading
# Task: Create a text file named greetings.txt and write the following lines 
# into it:
# Hello, world!
# Python is fun.
# File handling is a key skill.
# Write a Python script that opens this file, reads its entire content, 
# prints the content to the console, and then closes the file.
f = open('greetings.txt', 'wt')
f.write('Hello, world!\nPython is fun.\nFile handline is a key skill')
f.close()
with open('greetings.txt') as f:
    content = f.read()
    print(content)

# Challenge 2: Using the with Statement
# Task: Re-write the script from Challenge 1, but this time, use the with 
# statement to handle the file. This will ensure the file is closed automatically.
with open('greetings.txt') as f:
    content = f.read()
    print(content)


# Challenge 3: Reading Line by Line
# Task: Create a file named numbers.txt with the following content:
# 1
# 2
# 3
# 4
# 5

# Write a Python program that reads this file line by line and prints 
# each line to the console.
f = open('numbers.txt', 'wt')
f.write(' 1\n 2\n 3 \n 4 \n 5')
f.close()
with open('numbers.txt') as f:
    for line in f:
        print(line, end='')

# Challenge 4: Counting Lines
# Task: Using the numbers.txt file from Challenge 3, write a script that 
# counts the number of lines in the file and prints the total count.
# Use a for loop and counter
counter = 0
with open('numbers.txt') as f:
    for new_line in f:
        counter += 1
    print(counter)
# Use readlines and len
with open('numbers.txt') as f:
    content = f.readlines()
    print(len(content))

# Challenge 5: Reading a Specific Number of Characters
# Task: Create a file named long_text.txt with a single line of text that is at 
# least 30 characters long.
# Write a script that opens this file and reads only the first 10 characters. 
# Print these characters to the console.
f = open('long_text.txt', 'wt')
f.write('Helloworld!Python is fun.File handline is a key skill. GenAI is the future')
f.close()
with open('long_text.txt') as f:
    first_ten = f.read(10)
    print(first_ten)

# Challenge 6: The seek() Method
# Task: Using the long_text.txt file from Challenge 5, write a script 
# that opens the file, reads the first 5 characters, then uses 
# the seek() method to move the file cursor back to the beginning. 
# After moving the cursor, read the entire file and print its content.
with open('long_text.txt') as f:
    first_five = f.read(5)
    print(first_five)
    print('*' * 25)
    f.seek(0)
    print(f.read())

# Challenge 7: Understanding f.closed
# Task: Write a Python script that opens a file named status.txt 
# (it can be an empty file), prints the value of the closed attribute 
# before and after closing the file. The output should clearly show 
# False followed by True.
new_file = open('status.txt', 'wt')
new_file.write('New\nLine')
print(new_file.closed)
new_file.close()
print(new_file.closed)

# Challenge 8: Relative Paths
# Task: Imagine you have the following directory structure:
# project_folder/
# |-- main.py
# |-- data/
# |   |-- config.ini

# Your script main.py needs to read the content of config.ini. 
# Write the Python code in main.py that uses a relative path to open and 
# read config.ini, then print its content.

# Challenge 9: The readlines() Method
# Task: Create a file named quotes.txt with a few lines of your favorite quotes.
# Write a script that opens this file, uses the readlines() method to read 
# all the lines into a list, and then prints the list.
file = open('quotes.txt', 'wt')
file.write('This is a test.\nThis is a new line\nSo is this.')
file.close()
with open('quotes.txt') as f:
    content = f.readlines()
    print(content)

# Challenge 10: Processing readlines() Output
# Task: Using the list of lines obtained in Challenge 9, write a loop 
# that iterates through the list and prints each quote without the 
# newline character (\n) at the end.
with open('quotes.txt') as f:
    content = f.readlines()
    for line in content:
        print(line, end='')

# Challenge 11: Absolute Paths (Windows)
# Task: Create a file on your system at a specific location 
# (e.g., C:\temp\my_file.txt on Windows).
# Write a Python script that uses a raw string (r'...') to open this 
# file using its absolute path, read its content, and print it.
new_text = open(r'C:\Windows\Temp\my_file.txt', 'wt')
new_text.write('This is a test file for absolute paths.')
new_text.close()
with open(r'C:\Windows\Temp\my_file.txt', 'rt') as f:
    content = f.readlines()
    for line in content:
        print(line, end='')

# Challenge 12: Absolute Paths (Linux/macOS)
# Task: Create a file on your system at a specific location 
# (e.g., /home/user/documents/report.txt on Linux/macOS).
# Write a Python script that uses this absolute path to open the file, read 
# its content, and print it.

# Challenge 13: Using splitlines()
# Task: Create a file named multiline.txt with several lines of text.
# Write a script that reads the entire file content into a single string, 
# then uses the splitlines() method to create a list of lines. Print the 
# resulting list.
file = open('multiline.txt', 'wt')
file.write('Line 1\nLine 2\nLine 3\nLine 4')
file.close()
with open('multiline.txt') as f:
    single_string = f.read()
    lines_list = single_string.splitlines()
    print(lines_list)

# Challenge 14: Handling FileNotFoundError
# Task: Write a Python script that attempts to open a file that you know 
# does not exist. Your script should gracefully handle the FileNotFoundError 
# using a try...except block and print a user-friendly message 
# like "The file could not be found."
try:
    with open('test.txt', 'rt') as f:
        pass
except FileNotFoundError:
    print('The file could not be found.')

# Challenge 15: Reading with a Loop
# Task: Create a file named groceries.txt with a list of grocery items, one 
# item per line.
# Write a script that opens the file and uses a for loop to iterate directly 
# over the file object, printing each line.
file = open('groceries.txt', 'wt')
file.write('Apples\nGrapes\nSoda\nCheese')
file.close()
with open('groceries.txt', 'rt') as f:
    for lines in f:
        print(lines, end='')

# %%
# Out:
# Apples
# Grapes
# Soda
# Cheese
