# %%
# # 12. Challenges Test Your Skills - Python Strings

# Challenge #1

# A company has a revenue of 45,897,513.
# Calculate its profit, assuming profit is 12.7% of the revenue.
# Display the result rounded to two decimal places.
revenue = 45_897_513
profit = revenue * 12.7
print(f'Your profit is {profit:.2f}')

# Challenge #2!!!! Need further challanges for this method

# Consider the following string declaration which is part of the output of a  Linux command.
my_str = 'wlo1 Link encap:Ethernet  HWaddr b4:6d:83:77:85:f3'

# Write a Python script that extracts the MAC address (b4:6d:83:77:85:f3) from the string.
# Try to solve the challenge in more than one way.

# SOLUTION 1
mac = my_str[len(my_str)-17:]
print(mac)      # => b4:6d:83:77:85:f3

# SOLUTION 2
mac = my_str[-1:-18:-1]
mac = mac[::-1]     # reverse the string
print(mac)          # => b4:6d:83:77:85:f3


# SOLUTION 3
# Split the string into a list and return the last list element which is the MAC address
mac = my_str.split()[-1]
print(mac)     # => b4:6d:83:77:85:f3


# Challenge #3
# Display the following strings literally:
# It displayed: "You've got an error!"
# \n means a new line.
# \ is known as the escape character.
print("""It displayed: "you've got an error! 
\\n means a new line.
\\ is known as the escape.""")


# Challenge #4
# Write a Python script to convert feet (ft) to centimeters (cm).
# Conversion: 1 ft = 30.48 cm
# Prompt the user to enter a value in feet.
# Display the result in centimeters with two decimal places, formatted using an f-string.
feet = float(input('Enter Feet:'))
print(f'Centimeters: {feet * 30.48:.2f}')

# Challenge #5 !!!! Need further challanges for this method
# Write a Python script to check if a string is a palindrome.
# 1. Ask user for a word and immediately convert it to lowercase
word = input('Enter a word:').lower()

# 2. Create a reversed version of the word
reversed_word = word[::-1]

# 3. Use an if/else statement to compare the original word with its reversed version
if reversed_word == word:
    # If they are the same, it's a palindrome
    print('Your word is a palindrome')
else:
    # Otherwise, it's not a palindrome
    print('Your word is not a palindrome')


# Challenge #6
# Change the solution of the previous challenge to ignore whitespace and letter case when checking if a string is a palindrome.

# 1. Ask user for a word and immediately convert it to lowercase and remove whitespace
word = input('Enter a word:').lower().strip()

# 2. Create a reversed version of the word
reversed_word = word[::-1]

# 3. Use an if/else statement to compare the original word with its reversed version
if reversed_word == word:
    # If they are the same, it's a palindrome
    print('Your word is a palindrome')
else:
    # Otherwise, it's not a palindrome
    print('Your word is not a palindrome')

# Challenge #7
# Write a Python script that extracts the first and last two characters from a user-entered string.
# Example:
# Input: 'Hello!'
# Output: 'Heo!'
word = input('Enter a word:')
print(word[:2],word[-2:])

# Challenge #8
# Write a Python script that replaces all occurrences of the first character in a string with '$', except for the first occurrence itself.
# Example:
# Input: 'mama'
# Output: 'ma$a'
word = input('Enter a string:') # Get the user's input
first_char = word[0] # Store the very first character
#modified_rest_of_word = word[1:].replace(first_char, '$') # Could store in a var
print(first_char + word[1:].replace(first_char, '$')) # Combine the original first_char with the modified rest of the word

# The Challenge:
# You need to write a Python script that asks the user for two separate strings:
# A "main string"
# An "insert string"
# Your goal is to insert the "insert string" exactly in the middle of the "main string". If the "main string" has an odd number of characters, the "insert string" should be placed right after the single middle character.
# Finally, you should print the new, combined string.
# 1. Get user input for the main string
main_string = input('Enter the main string: ')

# 2. Get user input for the string to insert
insert_string = input('Enter the string to insert: ')

# 3. Get the length of the main string
length_of_main_string = len(main_string)

# 4. Calculate the middle index using integer division
middle = length_of_main_string // 2

# 5. Get the first part of the main string (before the insertion point)
first_part = main_string[:middle]

# 6. Get the second part of the main string (from the insertion point to the end)
second_part = main_string[middle:]

# 7. Combine the three parts in the correct order
#    (first part + insert string + second part)
final_combined_string = first_part + insert_string + second_part

# 8. Print the final result
print(final_combined_string)


# Challenge #9
# Write a Python program to remove the character at the nth index from a non-empty string.
# The nth index is provided by the user.
# 1. Get the main string from the user
user_string = input('Enter a string: ')

# 2. Get the 1-based position from the user and convert it to an integer
nth_position = int(input('Enter the position (1-based) of the character to remove: '))

# 3. Convert the 1-based position to a 0-based index for Python
index_to_remove = nth_position - 1

# --- Optional: Add a check for valid index if desired, though not asked for in walkthrough ---
# if index_to_remove < 0 or index_to_remove >= len(user_string):
#     print("Error: Position out of string range.")
# else:

# 4. Get the first part of the string (before the character to remove)
first_part = user_string[:index_to_remove]

# 5. Calculate the starting index for the second part (after the character to remove)
start_of_second_index = index_to_remove + 1

# 6. Get the second part of the string (after the character to remove)
second_part = user_string[start_of_second_index:]

# 7. Combine the two parts to form the new string with the character removed
final_string = first_part + second_part

# 8. Print the final result
print(final_string)
# Or can print directly
print(user_string[:index_to_remove] + user_string[start_of_second_index:])


# Challenge #10
# Write a Python script that removes characters at odd index positions from a given string.
# 1. Get the word from the user
word = input('Enter a word: ')

# 2. Initialize an empty string to build the result
new_word = ''

# 3. Initialize the index counter for the while loop
i = 0

# 4. Start the while loop: iterate as long as 'i' is a valid index
while i < len(word):
    # 5. Check if the current index 'i' is even
    if i % 2 == 0:
        # 6. If it's even, append the character at that index to new_word
        new_word = new_word + word[i]
    
    # 7. Increment 'i' to move to the next character in the original word
    i = i + 1

# 8. After the loop finishes, print the new string
print(new_word)


# Challenge #11
# Write a Python script that prompts the user for a circle's radius and calculates its area.
# Formula: Area = π * r² (π = 3.1415)
# Display the area with four decimal places using an f-string.
r = float(input('Enter a number:'))
area = 3.1415 * r ** 2
print(f'The radius you entered {r} equals {area:.4f}.')

# Challenge #12
# Write a Python script that counts the number of occurrences 
# of a substring in a given string, ignoring letter case.
# 1. Get the main string from the user and convert it to lowercase
word = input('Enter a string: ').lower()

# 2. Get the substring from the user and convert it to lowercase
sub = input('Enter a substring to count: ').lower()

# 3. Initialize a variable to count the occurrences
v = 0

# 4. Initialize the starting index for our search
start_index = 0

# 5. Perform the first search for the substring
#    found_index will store the starting position if found, or -1 if not
found_index = word.find(sub, start_index)

# 6. Start the loop: continue as long as the substring is found (found_index is not -1)
while found_index != -1: # or while found_index >= 0:
    # 7. Increment our counter because we found an occurrence
    v = v + 1 # or v += 1

    # 8. Update the start_index for the *next* search.
    #    We need to start searching *after* the current occurrence to avoid counting it again.
    start_index = found_index + len(sub)

    # 9. Perform the next search using the updated start_index.
    #    The result will update found_index for the next loop iteration's condition check.
    found_index = word.find(sub, start_index)

# 10. After the loop finishes (meaning no more occurrences were found), print the total count
print(v)

# Assuming word and sub are already in lowercase from your input steps
# word = input('...').lower()
# sub = input('...').lower()

count = word.count(sub)
print(count)

# Challenge #13
# Write a Python script to format a number using:
# US/UK format: A comma , as the thousands separator
# EU format: A period . as the thousands separator
# Example:
# Input: 1234567
# Output: 1,234,567 (US/UK) and 1.234.567 (EU)
# Out:
#   Cell In[3], line 20
#     print(new_str{-1})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Consider the following string declaration which is part of the output of a  Linux command.
my_str = 'wlo1 Link encap:Ethernet  HWaddr b4:6d:83:77:85:f3'

# Write a Python script that extracts the MAC address (b4:6d:83:77:85:f3) from the string.
# Try to solve the challenge in more than one way.

# SOLUTION 1
mac = my_str[len(my_str)-17:]
print(mac)      # => b4:6d:83:77:85:f3

# SOLUTION 2
mac = my_str[-1:-18:-1]
mac = mac[::-1]     # reverse the string
print(mac)          # => b4:6d:83:77:85:f3


# SOLUTION 3
# Split the string into a list and return the last list element which is the MAC address
mac = my_str.split()[-1]
print(mac)     # => b4:6d:83:77:85:f3
# Out:
# b4:6d:83:77:85:f3
# Mac Address (length of string): 49
# Last digit of the length: 9

# %%
# Challenge #8
# Write a Python script that replaces all occurrences of the first character in a string with '$', except for the first occurrence itself.
# Example:
# Input: 'mama'
# Output: 'ma$a'
word = input('Enter a string:') # Get the user's input
first_char = word[0] # Store the very first character
#modified_rest_of_word = word[1:].replace(first_char, '$') # Could store in a var
print(first_char + word[1:].replace(first_char, '$')) # Combine the original first_char with the modified rest of the word
# Out:
# ma$$a

# %%
# The Challenge:
# You need to write a Python script that asks the user for two separate strings:
# A "main string"
# An "insert string"
# Your goal is to insert the "insert string" exactly in the middle of the "main string". If the "main string" has an odd number of characters, the "insert string" should be placed right after the single middle character.
# Finally, you should print the new, combined string.
# 1. Get user input for the main string
main_string = input('Enter the main string: ')

# 2. Get user input for the string to insert
insert_string = input('Enter the string to insert: ')

# 3. Get the length of the main string
length_of_main_string = len(main_string)

# 4. Calculate the middle index using integer division
middle = length_of_main_string // 2

# 5. Get the first part of the main string (before the insertion point)
first_part = main_string[:middle]

# 6. Get the second part of the main string (from the insertion point to the end)
second_part = main_string[middle:]

# 7. Combine the three parts in the correct order
#    (first part + insert string + second part)
final_combined_string = first_part + insert_string + second_part

# 8. Print the final result
print(final_combined_string)
# Out:
#   Cell In[16], line 1
#     help(.replace)
#          ^
# SyntaxError: invalid syntax

# %%
# Challenge #10
# Write a Python script that removes characters at odd index positions from a given string.
# 1. Get the word from the user
word = input('Enter a word: ')

# 2. Initialize an empty string to build the result
new_word = ''

# 3. Initialize the index counter for the while loop
i = 0

# 4. Start the while loop: iterate as long as 'i' is a valid index
while i < len(word):
    # 5. Check if the current index 'i' is even
    if i % 2 == 0:
        # 6. If it's even, append the character at that index to new_word
        new_word = new_word + word[i]
    
    # 7. Increment 'i' to move to the next character in the original word
    i = i + 1

# 8. After the loop finishes, print the new string
print(new_word)
# Out:
# supeman

# %%
# Challenge #12
# Write a Python script that counts the number of occurrences 
# of a substring in a given string, ignoring letter case.
# 1. Get the main string from the user and convert it to lowercase
word = input('Enter a string: ').lower()

# 2. Get the substring from the user and convert it to lowercase
sub = input('Enter a substring to count: ').lower()

# 3. Initialize a variable to count the occurrences
v = 0

# 4. Initialize the starting index for our search
start_index = 0

# 5. Perform the first search for the substring
#    found_index will store the starting position if found, or -1 if not
found_index = word.find(sub, start_index)

# 6. Start the loop: continue as long as the substring is found (found_index is not -1)
while found_index != -1: # or while found_index >= 0:
    # 7. Increment our counter because we found an occurrence
    v = v + 1 # or v += 1

    # 8. Update the start_index for the *next* search.
    #    We need to start searching *after* the current occurrence to avoid counting it again.
    start_index = found_index + len(sub)

    # 9. Perform the next search using the updated start_index.
    #    The result will update found_index for the next loop iteration's condition check.
    found_index = word.find(sub, start_index)

# 10. After the loop finishes (meaning no more occurrences were found), print the total count
print(v)

# Assuming word and sub are already in lowercase from your input steps
# word = input('...').lower()
# sub = input('...').lower()

count = word.count(sub)
print(count)
# Out:
# The radius you entered 30.0 equals 2827.3500.
