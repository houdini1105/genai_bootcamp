# %%
# Chp7 Ep10. Challenges Test Your Skills - Working With Text Files
# Challenge #1
# You are given a text file that contains multiple duplicate MAC addresses.
# Create a Python script that generates a new file containing only unique 
# MAC addresses, with each address on a separate line.
# Open the file 'macs.txt' for reading with the alias 'f'
with open('macs.txt', 'rt') as f:
    # Read all lines from the file, split them into a list, and then convert to a set
    # The set automatically handles removing any duplicate MAC addresses
    new_file = set(f.read().splitlines())

# Open a new file named 'final_macs.txt' for writing with the alias 'f'
with open('final_macs.txt', 'wt') as f:
    # Loop through each unique MAC address stored in the 'new_file' set
    for mac in new_file:
        # Write each MAC address to the new file
        # The '\n' adds a new line after each address, putting each one on its own line
        f.write(mac + '\n')


# Challenge #2
# Create a Python script that reads a text file into a list, then converts the list into a single string containing the entire file content.
# 📁 Click to download a sample text file.
# [Stuck? Click here to see the solution.]



# Challenge #3
# Write a Python script that removes all empty lines, including lines that contain only spaces, from a text file.
# 📁 Click to download a sample text file.
# [Stuck? Click here to see the solution.]



# Challenge #4
# Create a Python function called tail that reads the last n lines of a text file.
# The function should accept two arguments: the file name and the number of lines to read (n).
# This mimics the behavior of the Linux tail command.
# Example:

# tail('sample_file.txt', 5)

# Returns the last 5 lines of sample_file.txt.
# 📁 Click to download a sample text file.
# [Stuck? Click here to see the solution.]



# Challenge #5
# Modify the previous solution so that the script automatically refreshes and prints the last n lines of the file every 3 seconds.
# This is similar to the Linux tail -f command.
# 📁 Click to download a sample text file.
# [Stuck? Click here to see the solution.]



# Challenge #6
# Write a Python program to count the number of lines, words, and characters in a text file — similar to the Linux wc command.
# Try to create a reusable function.
# 📁 Click to download a sample text file.
# [Stuck? Click here to see the solution.]



# Challenge #7
# Write a Python program that calculates the net amount in a bank account based on transactions listed in a text file.
# Each transaction is on a separate line, using this format:

# D:50 # Deposit
# W:100 # Withdrawal
# Example file content (click to download):

# D:300
# D:300
# W:500
# D:200
# Expected output: 300
# [Stuck? Click here to see the solution.]



# Challenge #8
# Write a Python script that compares two text files line by line and displays only the lines that differ.
# [Stuck? Click here to see the solution.]



# Challenge #9
# 📁 Consider this dictionary file.
# Write a Python script that reads the file into a dictionary, where each word becomes a key and the length of the word becomes the corresponding value.
# [Stuck? Click here to see the solution.]



# Challenge #10
# Using the dictionary created in the previous challenge, write a Python script that finds the first 100 longest words in the file.
# 💡 Tip: Look into how to get a sorted view of a dictionary.
# [Stuck? Click here to see the solution.]



# Challenge #11
# 📁 Consider the same dictionary file.
# Write a Python script that counts the occurrence of each letter (A-Z, a-z) in all the words of the dictionary.
# Make a distinction between lowercase and uppercase letters.
# At the end, identify:

# a) The most frequently used letter in the English dictionary
# b) The least frequently used letter in the English dictionary
# [Stuck? Click here to see the solution.]

# Challenge #12
# Update the previous solution so that the script ignores case — all letters should be counted as lowercase.
# [Stuck? Click here to see the solution.]



# Challenge #13
# Extend the previous challenge to find the three most frequently used letters across all words.
# Expected output:

# ('e', 67681), ('s', 50872), ('i', 50818)
