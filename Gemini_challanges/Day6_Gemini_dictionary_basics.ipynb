# %%
# Challenge 1: Creating a Dictionary from Lists
# Challenge: You have two lists: one for keys and one for values. Create a dictionary from these lists.
# keys = ['apple', 'banana', 'cherry']
# values = [1.0, 0.5, 2.0]
# Your goal is to create a dictionary where
#  'apple' maps to 1.0, 'banana' to 0.5, and 'cherry' to 2.0.
# Walkthrough:
# Python has a built-in function that is perfect for creating a 
# dictionary from two lists, where one list provides the keys and the 
# other provides the corresponding values. This function often works well 
# with another function that combines elements from multiple iterables.
# What should you do next?
# What built-in functions might you consider using to pair up the items 
# from the keys and values lists and turn them into a dictionary?
keys = ['apple', 'banana', 'cherry']
values = [1.0, 0.5, 2.0]
my_dict = dict(zip(keys, values))
print(my_dict)

# Challenge 2: Deleting a Key-Value Pair
# Challenge: You have a dictionary of game scores. 
# Remove the entry for 'PlayerC'.
# Python
# game_scores = {'PlayerA': 100, 'PlayerB': 150, 'PlayerC': 75}
# Walkthrough:
# Dictionaries have a keyword that allows you to remove a specific 
# key-value pair. You use this keyword followed by the dictionary name 
# and the key you want to remove in square brackets.
# What should you do next?
# How would you write the line of code to remove 'PlayerC' and its score 
# from game_scores?

# Challenge 3: Combining Dictionaries
# Challenge: You have two separate dictionaries representing parts of an inventory. Combine them into a single new dictionary.

# Python

# inventory_part1 = {'shirts': 20, 'pants': 15}
# inventory_part2 = {'shoes': 10, 'hats': 5}
# Create a new dictionary called full_inventory that contains all items from both inventory_part1 and inventory_part2.

# Walkthrough:
# There are several ways to combine dictionaries. One common way for Python 3.5+ is to use a special unpacking operator (**) which works well when creating a new dictionary. Another method involves using a dictionary's update() method.

# What should you do next?
# How would you combine these two dictionaries into full_inventory using the unpacking operator?

# Challenge 4: Clearing a Dictionary
# Challenge: Empty the following dictionary, removing all its key-value pairs.

# Python

# temp_data = {'sensor_id': 'XYZ001', 'temperature': 25.5, 'humidity': 60}
# Walkthrough:
# Dictionaries have a built-in method specifically designed to remove all items from them, making them empty. This method doesn't take any arguments.

# What should you do next?
# What method would you call on temp_data to clear it?

# Challenge 5: Iterating Through Key-Value Pairs
# Challenge: Print out both the key and the value for each item in the product_prices dictionary, formatted like: "Product: [key], Price: [value]".

# Python

# product_prices = {'laptop': 1200, 'mouse': 25, 'keyboard': 75}
# Walkthrough:
# When you want to iterate over both the keys and their corresponding values in a dictionary simultaneously, there's a specific dictionary method that returns pairs of (key, value) tuples. You can then unpack these tuples directly in your for loop.

# What should you do next?
# What dictionary method would you use in your for loop, and how would you structure the print() statement inside the loop?

# Challenge 6: Using in for Key Existence Check
# Challenge: Check if the key 'email' exists in the user_settings dictionary. Print "Email setting exists" if it does, and "Email setting missing" otherwise.

# Python

# user_settings = {'theme': 'dark', 'notifications': True}
# Walkthrough:
# Python provides a convenient operator to check for the presence of an element within a collection (like a key in a dictionary). It's typically used in an if statement.

# What should you do next?
# How would you write an if/else statement using this operator to perform the check?

# Challenge 7: Dictionary Comprehension (Introductory)
# Challenge: Create a new dictionary called squared_numbers where the keys are numbers from 1 to 5, and the values are the square of those numbers.

# Your final dictionary should look like: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}.

# Walkthrough:
# While you could use a for loop, Python offers a more concise way to create dictionaries (and lists, sets) based on existing iterables or a range, called "dictionary comprehension." It looks similar to a for loop but is written within the dictionary's curly braces.

# What should you do next?
# How would you write this using dictionary comprehension, iterating through a range() of numbers?

# Challenge 8: Dictionary with Mixed Value Types
# Challenge: Create a dictionary called user_data for a single user. It should contain:

# A string for 'username' (e.g., 'john_doe')

# an integer for 'id' (e.g., 101)

# a boolean for 'is_active' (e.g., True)

# a list of strings for 'roles' (e.g., ['admin', 'editor'])

# Walkthrough:
# This challenge reinforces that dictionary values can be of any data type, including other complex types like lists. You just need to correctly define each key-value pair within the dictionary's curly braces.

# What should you do next?
# How would you define the user_data dictionary with all these specified key-value pairs?

# Challenge 9: Accessing a Value in a Nested List within a Dictionary
# Challenge: From the student_grades dictionary, extract and print the grade 'B' for 'Mathematics'.

# Python

# student_grades = {
#     'Alice': {'Physics': 85, 'Chemistry': 90, 'Mathematics': [70, 'B']},
#     'Bob': {'Physics': 75, 'Chemistry': 80, 'Mathematics': [65, 'C']}
# }
# Walkthrough:
# This requires multiple levels of access. First, you'll need to access the dictionary for 'Alice'. Then, within 'Alice's dictionary, you'll access the value for 'Mathematics', which is a list. Finally, you'll need to access the correct element from that list.

# What should you do next?
# How would you string together the key and index accesses to get to the 'B' grade?

# Challenge 10: Updating Multiple Values at Once
# Challenge: The product_stock dictionary needs to have its 'chairs' stock updated to 25 and a new item 'desks' added with a stock of 10.

# Python

# product_stock = {'tables': 5, 'chairs': 20}
# Walkthrough:
# While you could do this with two separate assignment statements, dictionaries have a method that allows you to update existing key-value pairs and add new ones from another dictionary or an iterable of key-value pairs. This can be more efficient for multiple changes.

# What should you next?
# What method would you use on product_stock to apply both updates in one step?

# %%
# Out:
# {'apple': 1.0, 'banana': 0.5, 'cherry': 2.0}
