# %%
# Here are 15 coding challenges to help you practice conditional statements, indentation, boolean variables, and logical operators in Python.

# Challenge 1: Age Classifier
# Write a Python program that asks the user to enter their age. 
# Based on the age, print one of the following messages:
# "You are a child." if age is less than 13.
# "You are a teenager." if age is between 13 and 19 (inclusive).
# "You are an adult." if age is 20 or greater.
age = int(input('Enter age:'))
if age < 13:
    print('You are a child.')
elif age >= 13 and age <= 19:
    print('You are a teenager.')
else:
    print('You are an adult.')

# Challenge 2: Even or Odd
# Write a program that takes an integer as input from the user. 
# Print whether the number is "Even" or "Odd". 
# (Hint: Use the modulo operator % to check for divisibility by 2).
num = int(input('Enter num:'))
if num % 2 == 0:
    print('Even')
else:
    print('Odd')

# Challenge 3: Positive, Negative, or Zero
# Create a program that prompts the user to enter a number. 
# Determine if the number is "Positive", "Negative", or "Zero" and print 
# the corresponding message.
num = int(input('Enter num:'))
if num > 0:
    print('Positive')
elif num < 0:
    print('Negative')
else: # If it's not positive and not negative, it must be zero
    print('Zero')

# Challenge 4: Login Check
# Imagine you have a username variable set to "admin" and a 
# password variable set to "password123". Write a program that asks 
# the user for a username and password. If both match the predefined values, 
# print "Login Successful!". Otherwise, print "Invalid Credentials.".
username = input('Enter username')
password = input('Enter password')
if username == 'admin' and password == 'password123':
    print('Login Successful')
else:
    print('Invalid')

# Challenge 5: Discount Calculator
# A store offers a 10% discount if a customer spends more than $100. 
# Write a program that asks the user for their total purchase amount. 
# Calculate and print the final amount after applying the discount if 
# applicable.
amount = float(input('Enter amount'))
if amount >= 100.00:
    print(amount * 0.90)   
else:
    print(amount)

# Challenge 6: Pass/Fail Grade
# Ask the user to enter a student's score (out of 100). If the score is 60 
# or above, print "Pass". Otherwise, print "Fail".
score = int(input('Enter score up to 100:'))
if score >= 60:
    print('Pass')
else:
    print('Fail')

# Challenge 7: Day of the Week
# Write a program that takes a number from 1 to 7 as input (representing days 
# of the week, where 1 is Monday, 2 is Tuesday, etc.). Print the corresponding 
# day name. If the number is outside this range, print "Invalid day number.".
day = int(input('Enter a num'))
if day == 1:
    print('Monday')
elif day == 2:
    print('Tuesday')
elif day == 3:
    print('Wednesday')
elif day == 4:
    print('Thursday')
elif day == 5:
    print('Friday')
elif day == 6:
    print('Saturday')
elif day == 7:
    print('Sunday')
else:
    print('Out of range')

# Challenge 8: Can Vote?
# Ask the user for their age and citizenship status (e.g., "yes" or "no"). 
# Determine if they are eligible to vote (must be 18 or older AND a citizen) 
# and print "Eligible to Vote" or "Not Eligible to Vote".
age = int(input('Enter age:'))
citz = input('Enter Yes or No:').lower()
if age >= 18 and citz == 'yes':
    print('Eligible to Vote')
else:
    print('Not Eligible to Vote')

# Challenge 9: Empty String Check
# Write a program that asks the user to enter their name. If the user enters an
# empty string, print "Name cannot be empty!". Otherwise, print 
# "Hello, [Name]!". (Hint: Remember how empty strings evaluate in a 
# boolean context).
name = input('Enter Name')
if name:
    print(f'Hello, {name}!')
else:
    print('Name cannot be empty.')

# Challenge 10: Boolean Arithmetic
# Given two boolean variables: is_member = True and has_coupon = False.
# Write a program that calculates total_discounts = is_member + has_coupon and 
# prints the total_discounts. Explain why you get that specific number.
is_member = True
has_coupon = False
if is_member + has_coupon > 0:
    print(is_member + has_coupon)
# Because True = 1, False = 0 for a total of 1

# Challenge 11: Weekend or Weekday
# Ask the user to enter a day of the week (e.g., "Monday", "Saturday"). 
# Print "It's the Weekend!" if it's Saturday or Sunday, and "It's a Weekday." 
# for any other valid day.
day = input('Enter a day:').lower()
if day == 'saturday' or day == 'sunday':
    print('It\'s the weekend!')
else:
    print('It\'s a weekday.')

# Challenge 12: Temperature Advice
# Extend the temperature example. Ask the user for the temperature and
# whether it's raining (True/False).
# If it's freezing (< 0) and raining, print "Stay indoors, it's dangerous!".
# If it's cold (< 15) and raining, print "Wear a waterproof jacket!".
# Otherwise, use the original temperature advice from the reference material.

# Get temperature input from the user
temp = int(input('Enter temperature in Celsius:'))

# Get raining status input from the user and convert it to a boolean
# We convert the input to lowercase and then compare it to 'yes'
# This ensures that 'True' is assigned only if the user explicitly types 'yes'.
raining_input = input('Is it raining? Enter "yes" or "no": ').lower()
is_raining = (raining_input == 'yes')

# Apply the extended conditional logic
if temp < 0 and is_raining:
    print('Stay indoors, it\'s dangerous!')
elif temp < 15 and is_raining:
    print('Wear a waterproof jacket.')
else:
    # If neither of the specific raining conditions are met,
    # then apply the original temperature advice.
    # This block handles cases where it's not raining, or
    # it's raining but not in the freezing/cold categories.
    if temp < 0:
        print("It's freezing, wear a coat!")
    elif temp < 15:
        print("It's cold, you might need a jacket.")
    elif temp < 27:
        print("The weather is mild.")
    else:
        print("It's hot, wear shorts.")
    

# Challenge 13: Short-Circuit and
# Predict what will be printed and then write a program to confirm:

# value = 0
# if value > 5 and print("Condition 2 evaluated"):
#     print("Both conditions true")
# else:
#     print("First condition false or short-circuited")

# Explain why Condition 2 evaluated might or might not be printed.
# The key concept is short-circuit evaluation with the and operator.

# Challenge 14: Short-Circuit or
# Predict what will be printed and then write a program to confirm:
# name = "Alice"
# if name == "Alice" or print("Condition 2 evaluated"):
#     print("Hello Alice!")
# else:
#     print("Name is not Alice")
# Explain why Condition 2 evaluated might or might not be printed.
# Hello Alice will print since the first condition has been met True with the or operator

# Challenge 15: Nested Conditions
# Write a program that asks for a user's age and if they have a 
# valid ID (True/False).
# If they are 18 or older:
# If they have a valid ID, print "Entry Granted."
# Else, print "ID required for entry."
# Else (if they are under 18), print "Too young for entry."
age = int(input('Enter age:'))
valid_id = input('Do you have valid ID? Enter Yes or No:').lower()
id = (valid_id == 'yes')
if age >= 18:
    if id:
        print('Entry Granted.')
    elif not id:
        print('Need valid ID')
else:
    print('To young for entry.')

# %%
# Out:
# Entry Granted.
