# %% [markdown]
# # Day 3 String challange
# Here's a 20-question Python coding challenge focused on common string methods such as:
#
# .upper()
#
# .lower()
#
# .strip()
#
# .split()
#
# .replace()
#
# .count()
#
# .join()
#
# .startswith(), .endswith()
#
# .find(), .index()
#
# .title()
#
# .capitalize()
#
# 🐍 Python String Methods – 20 Practice Challenges
# 1. Shouting Text
# Ask the user to enter a sentence. Print it in all uppercase using .upper().
#
# 2. Whispering Text
# Ask the user to enter a sentence. Print it in all lowercase using .lower().
#
# 3. Trim the Edges
# Ask the user to enter a sentence with extra spaces at the beginning and end. Use .strip() to remove them and print the cleaned result.
#
# 4. Split a Sentence
# Ask for a sentence. Use .split() to convert it into a list of words, and print the list.
#
# 5. Count a Word
# Ask for a sentence and a word. Use .count() to print how many times the word appears in the sentence.
#
# 6. Replace a Word
# Ask for a sentence. Replace every occurrence of the word "bad" with "good" using .replace().
#
# 7. Word Joiner
# Ask for three words. Combine them into one string separated by hyphens using "-".join().
#
# 8. Title Casing
# Ask for a sentence and print it in title case using .title().
#
# 9. Capitalize First Letter
# Ask for a sentence and print it with only the first letter capitalized using .capitalize().
#
# 10. Check Start of String
# Ask for a string. Use .startswith("Hello") to check if it starts with "Hello" and print True or False.
#
# 11. Check End of String
# Ask for a string. Use .endswith("!") to check if it ends with an exclamation mark and print the result.
#
# 12. Word Location
# Ask for a sentence and a word. Use .find() to find the index of the first occurrence of the word and print it.
#
# 13. Word Location with Error Handling
# Same as above, but use .find() and check if the word exists before printing its index (if not found, return -1 or a message).
#
# 14. Character Count
# Ask for a string and a letter. Use .count() to print how many times the letter appears.
#
# 15. Remove All Spaces
# Ask the user for a sentence. Remove all spaces using .replace(" ", "") and print the result.
#
# 16. Clean and Split
# Ask for a messy sentence with leading/trailing spaces and multiple spaces between words. Use .strip() and .split() to clean and separate it into words.
#
# 17. Email Validator
# Ask for an email. Use .find("@") and .endswith(".com") to check if it's formatted correctly.
#
# 18. Reverse Words
# Ask the user for a sentence. Split it into words and print them in reverse order.
#
# 19. Join First Letters
# Ask for a sentence. Use .split() to extract the first letter of each word and join them into an acronym.
#
# 20. Replace Vowels
# Ask the user for a word. Replace all vowels (a, e, i, o, u) with *.

# %%
# Here's a 20-question Python coding challenge focused on common string methods such as:

# .upper()

# .lower()

# .strip()

# .split()

# .replace()

# .count()

# .join()

# .startswith(), .endswith()

# .find(), .index()

# .title()

# .capitalize()

# 🐍 Python String Methods – 20 Practice Challenges
# 1. Shouting Text
# Ask the user to enter a sentence. Print it in all uppercase using .upper().
sentence = input('Enter a sentence:')
#sentence_upper = sentence.upper() # can put into a variable
print(sentence.upper()) # display using upper()

# 2. Whispering Text
# Ask the user to enter a sentence. Print it in all lowercase using .lower().
sentence = input('Enter a sentence:')
#sentence_upper = sentence.lower() # can put into a variable
print(sentence.lower()) # display using lower()

# 3. Trim the Edges
# Ask the user to enter a sentence with extra spaces at the beginning and end. Use .strip() to remove them and print the cleaned result.
sentence = input('Enter a sentence with extra white spaces:')
cleaned = sentence.strip() # can store in a variable
print(sentence.strip()) # display using strip()

# 4. Split a Sentence
# Ask for a sentence. Use .split() to convert it into a list of words, and print the list.
sentence = input('Enter a sentence:')
sentence_split = sentence.split()
print(sentence_split)

# 5. Count a Word
# Ask for a sentence and a word. Use .count() to print how many times the word appears in the sentence.
sentence = input('Enter a sentence:')
word = input('Enter a word:')
count = word.count(sentence)
print(count)
# 6. Replace a Word
# Ask for a sentence. Replace every occurrence of the word "bad" with "good" using .replace().
sentence = input('Enter a sentence:').lower() # added .lower() for case sensitive
word = input('Enter a word:').lower() # added .lower() for case sensitive
count = sentence.count(word) # use count()
print(count)
# 7. Word Joiner
# Ask for three words. Combine them into one string separated by hyphens using "-".join().
word_one = input('Enter first word:')
word_two = input('Enter second word:')
word_three = input('Enter third word:')
combined_words = [word_one, word_two, word_three] # create a list of the words
sentence = "-".join(combined_words) # .join() the combined words
print(sentence)

# 8. Title Casing
# Ask for a sentence and print it in title case using .title().
sentence = input('Enter a sentence:')
sentence_split = sentence.title() # .title() uppercase the first letter of the sentence
print(sentence_split)#.title() could be used to print instead of assigning variable

# 9. Capitalize First Letter
# Ask for a sentence and print it with only the first letter capitalized using .capitalize().
sentence = input('Enter a sentence:')
sentence_cap = sentence.capitalize() # .capitalized() assigned to variable
print(sentence_cap.capitalize())#.capitalize() could be used to print instead of assiging variable

# 10. Check Start of String
# Ask for a string. Use .startswith("Hello") to check if it starts with "Hello" and print True or False.
enter_string = str(input('Enter a string:'))
start_string = enter_string.startswith('Hello') # .startswith() assigned to variable
print(start_string)#.startswith() can be used here instead of assigning variable

# 11. Check End of String
# Ask for a string. Use .endswith("!") to check if it ends with an exclamation mark and print the result.
enter_string = str(input('Enter a string:'))
start_string = enter_string.endswith('!') # .endswith() assigned to variable
print(start_string)#.endswith() can be used here instead of assigning variable

# 12. Word Location
# Ask for a sentence and a word. Use .find() to find the index of the first occurrence of the word and print it.
sentence = input('Enter a sentence:').lower() # added .lower() for case sensitive
word = input('Enter a word:').lower() # added .lower() for case sensitive
locate = sentence.find(word) # use find() to locate index in string
print(f'Your word {word} was located at the index of {locate} of first occurence.')

# 13. Word Location with Error Handling
# Same as above, but use .find() and check if the word exists before printing its index (if not found, return -1 or a message).
sentence = input('Enter a sentence:').lower() # added .lower() for case sensitive
word = input('Enter a word:').lower() # added .lower() for case sensitive
locate = sentence.find(word) # Use find() to get the index of the first occurrence
print(type(locate))
if locate != -1: # .find() returns -1 if the word is not found
    print(f"The word '{word}' was found at index {locate}.")
else:
    print(f"The word '{word}' was not found in the sentence.")
    print("It returned -1 because it was not found.")

# 14. Character Count
# Ask for a string and a letter. Use .count() to print how many times the letter appears.
# 14. Character Count
# Ask for a string and a letter. Use .count() to print how many times the letter appears

word = input('Enter a word:').lower()   # Get the word and convert to lowercase
letter = input('Enter a letter:').lower() # Get the letter and convert to lowercase
count = word.count(letter)             # Use .count() to find occurrences
print(count)                           # Print the count

# 15. Remove All Spaces
# Ask the user for a sentence. Remove all spaces using .replace(" ", "") and print the result.
sentence = input('Enter a sentence:')  # Get the sentence from the user
print(sentence.replace(' ', ''))       # Replace all spaces with an empty string and print

# 16. Clean and Split
# Ask for a messy sentence with leading/trailing spaces and multiple spaces
# between words. Use .strip() and .split() to clean and separate it into words.

messy_sent = input('Enter a sentence with leading/trailing/multiple spaces:')

stripped_sent = messy_sent.strip() # Step 1: Remove leading/trailing whitespace

# Step 2: Split the string into a list of words.
# .split() without arguments handles multiple internal spaces by treating
# any sequence of whitespace as a single delimiter and discarding empty strings.
splitted_sent = stripped_sent.split()

# Step 3: Join the words back together with a single space to standardize spacing.
clean_sent = ' '.join(splitted_sent)

print(clean_sent)

# 17. Email Validator
# Ask for an email. Use .find("@") and .endswith(".com") to check if it's formatted correctly.

# 18. Reverse Words
# Ask the user for a sentence. Split it into words and print them in reverse order.

# 19. Join First Letters
# Ask for a sentence. Use .split() to extract the first letter of each word and join them into an acronym.

# 20. Replace Vowels
# Ask the user for a word. Replace all vowels (a, e, i, o, u) with *.
# Out:
# THIS IS A TEST

# %%
# 16. Clean and Split
# Ask for a messy sentence with leading/trailing spaces and multiple spaces
# between words. Use .strip() and .split() to clean and separate it into words.

messy_sent = input('Enter a sentence with leading/trailing/multiple spaces:')

# Step 1: Remove leading/trailing whitespace
stripped_sent = messy_sent.strip()

# Step 2: Split the string into a list of words.
# .split() without arguments handles multiple internal spaces by treating
# any sequence of whitespace as a single delimiter and discarding empty strings.
splitted_sent = stripped_sent.split()

# Step 3: Join the words back together with a single space to standardize spacing.
clean_sent = ' '.join(splitted_sent)

print(clean_sent)
# Out:
# ijifj ijifj ijfoij s ps kdo
