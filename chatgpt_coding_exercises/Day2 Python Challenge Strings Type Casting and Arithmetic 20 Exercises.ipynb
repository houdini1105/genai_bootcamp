# %% [markdown]
# Day2 Python Challenge Strings Type Casting and Arithmetic 20 Exercises
# String Concatenation
# Full Name
# Ask the user for their first and last name. Print their full name on one line.
#
# Create a Username
# Ask for the user’s first name and a number. Combine them into a simple username (e.g., john23).
#
# Funny Sentence
# Ask for a noun, verb, and adjective, then print a sentence like:
# "The [adjective] [noun] loves to [verb]."
#
# Repeat a Word
# Ask for a word and a number, and print the word repeated that many times using string multiplication.
#
# Welcome Message
# Ask for a name and print: "Welcome, [name]!" with a border made of "=" that matches the length of the message.
#
# Type Casting and Conversion
# Add Two Numbers (as Strings)
# Ask the user to enter two numbers as strings. Convert them to int and print the sum.
#
# Float Input Test
# Ask for a number with a decimal. Convert it to float, add 1.5, and print the result.
#
# String to Int to String
# Take a number as input, cast it to int, add 10, and print the result as part of a sentence like: "Your new score is 25".
#
# Length of Number
# Ask for a number, convert it to a string, and print how many digits it has using len().
#
# Mixing Types
# Ask for a string and a number. Print them together in one sentence (you’ll need to cast the number to a string).
#
# 11. Make a Hashtag
# Ask the user for a word and print it as a hashtag by prepending # and converting it to lowercase.
#
# 📥 Input: Coding
# 📤 Output: #coding
#
# 12. Add Dollar Sign to Price
# Ask the user for a number. Convert it to a float and print it formatted with a dollar sign, like:
# Price: $4.99
#
# 13. Capitalize First Letter
# Ask for a sentence. Print the same sentence with the first letter capitalized using .capitalize().
#
# 14. Extract First Character
# Ask the user for a word. Print the first and last character of the word using indexing.
#
# 15. Simple Password Generator
# Ask for the user's name and favorite number. Combine them into a "password" like:
# name + str(number) + "!"
#
# 16. Convert KM to Miles
# Ask for a distance in kilometers. Convert it to miles using:
# miles = km * 0.621371
#
# 17. Find the Middle Digit
# Ask the user for a 3-digit number. Convert it to a string and print the middle digit.
#
# 18. Seconds in a Day
# Calculate how many seconds are in a day using arithmetic only (no input needed).
#
# 19. Even or Odd
# Ask for a number and print whether it is even or odd using the modulo % operator.
#
# 20. Word Length Checker
# Ask the user for a word. Print the word and how many letters it contains.
#
# 📥 Input: elephant
# 📤 Output: The word 'elephant' has 8 letters.

# %%
# Day2 Python Challenge Strings Type Casting and Arithmetic 20 Exercises
# String Concatenation
# Full Name
# Ask the user for their first and last name. Print their full name on one line.
first = input('Enter your first name:') # str input
last = input('Enter your last name') # str input
print(f'Your full name is {first} {last}') # display name using f-string
print('Your full name is: ' + first +' ' + last) # display using addition method

# Create a Username
# Ask for the user’s first name and a number. Combine them into a simple username (e.g., john23).
first = input('Enter your first name:') # str input
last = input('Enter your number') # str input
username = first + last
print('Your userid is: ' + first + last) # display using addition method
print('Your userid is:', username)

# Funny Sentence
# Ask for a noun, verb, and adjective, then print a sentence like:
# "The [adjective] [noun] loves to [verb]."
adjective = input('Enter a adjective:')
noun = input('Enter a noun:')
verb = input('Enter a verb:')
print('The ' + adjective.lower()  +  noun.lower() + ' loves to ' + verb.upper()) # display using addition method
print(f'The {adjective} {noun} loves to {verb}.')

# Repeat a Word
# Ask for a word and a number, and print the word repeated that many times using string multiplication.
word = input('Enter a word:')
number = int(input('Enter the # of times want repeated:'))
total = word * number
print(total)
print(word * number)

# Welcome Message
# Ask for a name and print: "Welcome, [name]!" with a border made of "=" that matches the length of the message.
name = input("Enter your name: ")
message = f"Welcome, {name}!"
print("=" * len(message))
print(message)
print("=" * len(message))

# Type Casting and Conversion
# Add Two Numbers (as Strings)
# Ask the user to enter two numbers as strings. Convert them to int and print the sum.
first = input('Enter first #:')
second = input('Enter second #:')
new_first = float(first) # convert to float, cna also convert during input
new_second = float(second) # converto to float, can also convert during input
print('Your total is:', new_first * new_second)
print(type(new_first), type(new_second))

# Float Input Test
# Ask for a number with a decimal. Convert it to float, add 1.5, and print the result.
number = input('Enter a # with a decimal:')
new_number = float(number) + 1.5 # convert to float and use add method
print(new_number)

# String to Int to String
# Take a number as input, cast it to int, add 10, and print the result as part of a sentence like: "Your new score is 25".
num = input('Enter a number:')
new_num = int(num) + 10
print('Your new score is:' + str(new_num)) # convert int to str to add and print

# Length of Number
# Ask for a number, convert it to a string, and print how many digits it has using len().
num = int(input('Enter a number:')) # using floar adds 2 additional zeros for the decimal even if not entered
convert_num = str(num) # convert int to str
print(len(convert_num)) # display length

# Mixing Types
# Ask for a string and a number. Print them together in one sentence (you’ll need to cast the number to a string).
word = input('Enter a word:')
num = input('Enter a number:') # input default value is str
print(word + num)

# 11. Make a Hashtag
# Ask the user for a word and print it as a hashtag by prepending # and converting it to lowercase.
word = input('Enter a word:')
lower_word = word.lower()
print('#' + lower_word)
# 📥 Input: Coding
# 📤 Output: #coding

# 12. Add Dollar Sign to Price
# Ask the user for a number. Convert it to a float and print it formatted with a dollar sign, like:
# Price: $4.99
number = float(input('Enter a number:'))
print('Price:$' + number)

# 13. Capitalize First Letter
# Ask for a sentence. Print the same sentence with the first letter capitalized using .capitalize().
sentence = input('Enter a sentence:')
new_sentence = sentence.capitalize() # uppercase the first character
print(new_sentence)
# Using the split method
sentence = input('Enter a sentence:') # Replace with your input sentence
finished_sentence = sentence[0].upper() + sentence[1:] # Uppercase the first index and add the remaining from index 1:
print(finished_sentence)
# Using the split method II
sentence = "this is a sample sentence." # Replace with your input sentence
sentence_split = sentence.split()

if sentence_split: # Ensure the list is not empty
    first_word = sentence_split[0]
    # Uppercase the first character of the first word
    first_char_upper = first_word[0].upper()
    # Reconstruct the first word with the uppercased first character
    new_first_word = first_char_upper + first_word[1:]

    # Join the modified first word with the rest of the words
    # If there's only one word, the slice [1:] will be empty, which is fine
    finished_sentence = new_first_word + " " + " ".join(sentence_split[1:])
    print(finished_sentence)
else:
    print("The input sentence is empty.")

# 14. Extract First Character
# Ask the user for a word. Print the first and last character of the word using indexing.
word = input('Enter a word:')
print(word[0]) # display index 0
print(word[-1]) # display index -1

# 15. Simple Password Generator
# Ask for the user's name and favorite number. Combine them into a "password" like:
# name + str(number) + "!"
first = input('Enter your first name:') # str input
last = input('Enter your number') # str input
username = first + last
print('Your userid is: ' + first + last) # display using addition method
print('Your userid is:', username)

# 16. Convert KM to Miles
# Ask for a distance in kilometers. Convert it to miles using:
# miles = km * 0.621371
kilometers = float(input('Enter miles:')) # using float instead of int
conversion = kilometers * 0.621371
print(f'Your distance in miles is {conversion}.')

# 17. Find the Middle Digit
# Ask the user for a 3-digit number. Convert it to a string and print the middle digit.
three_dig = int(input('Enter a three digit #:')) # enter as int instead of str
convert = str(three_dig) # convert from int to str (default is str)
print(convert[1]) # display index 1
# 18. Seconds in a Day
# Calculate how many seconds are in a day using arithmetic only (no input needed).

# 19. Even or Odd
# Ask for a number and print whether it is even or odd using the modulo % operator.
num = int(input('Enter a #:'))

if num % 2 == 0:
    print('Your # is even')
else:
    print('Your # is odd')

# 20. Word Length Checker
# Ask the user for a word. Print the word and how many letters it contains.
word = input('Enter a word:')
count = len(word) # use len() to count
print(f'Your word is {word} and has {count} letters.') # display using f-string

# 21. Bonus Question
# Enter a word, display the word entered and total amount of characters and check if it has even or odd amount of characters
word = input('Enter a word')
word_count = len(word) # use len() to get # of characters
if word_count % 2 == 0: # use modulus to check len if anything remains
    print(f'The word {word} is {word_count} characters & even') # display using f-string
else:
    print(f'The word {word} is {word_count} characters & odd')
# Out:
#   Cell In[23], line 115
#     word = input{'Enter a word:'}
#                 ^
# SyntaxError: invalid syntax

# %%
# Out:
# The word ssuperman is 9 characters & odd

# %%
# Out:
# The word superman is 8 characters & even
