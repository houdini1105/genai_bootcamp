# %%
# Challenge 1: Creating Tuples
# Goal: Create a simple tuple to store information about a book.
# Think about what kind of information you'd want to store 
# for a book (e.g., title, author, publication year).
# Choose at least three pieces of information.
# Create a tuple named book_info containing these three pieces of information.
book_inf0 = ('AI bootcamp', 'the_author', 2025)
print(type(book_inf0))

# Challenge 2: Empty and Single-Element Tuples
# Goal: Practice creating empty tuples and a tuple with just one element.
# Steps:
# Create an empty tuple called empty_data using both methods shown 
# in the reference.
# Create a tuple named single_item_tuple that contains only 
# the number 100. Remember the crucial detail for single-element tuples!
empty_data1 = tuple()
empty_data2 = ()
single_item_tuple = (69, )


# Challenge 3: Tuple from Other Data Types
# Goal: Convert a list and a string into tuples.
# Steps:
# Create a list named my_list with at least 5 numbers.
# Convert my_list into a tuple named tuple_from_list using the tuple() 
# constructor.
# Create a string named my_string with your name.
# Convert my_string into a tuple named tuple_from_string.
my_list = [1, 2, 3, 4, 5]
tuple_from_list = tuple(my_list)
print(type(tuple_from_list))
my_string = 'Your Name'
tuple_from_string = tuple(my_string)
print(type(tuple_from_string))


# Challenge 4: Accessing Elements by Index
# Goal: Retrieve specific elements from a tuple using indexing.
# Steps:
# Consider the book_info tuple you created in Challenge 1.
# Print the first element of book_info.
# Print the last element of book_info using negative indexing.
book_inf0 = ('AI bootcamp', 'the_author', 2025)
print(book_inf0[0])
print(book_inf0[-1])



# Challenge 5: Unpacking Tuples
# Goal: Unpack the elements of a tuple into individual variables.
# Steps:
# Create a tuple named student_details containing a 
# student's name, age, and grade (e.g., ("Alice", 15, "10th")).
# Unpack the student_details tuple into three separate
# variables: name, age, and grade.
# Print the values of name, age, and grade to verify the unpacking.
student_details = ('Alice', 15, '10th')
name, age, grade = student_details
print(name, age, grade)


# Challenge 6: Concatenating Tuples
# Goal: Combine two tuples into a new, single tuple.
# Steps:
# Create a tuple named tuple_part1 with the numbers (1, 2, 3).
# Create another tuple named tuple_part2 with the numbers (4, 5, 6).
# Concatenate tuple_part1 and tuple_part2 to create a new tuple 
# named combined_tuple.
# Print combined_tuple.
tuple_part1 = (1, 2, 3)
tuple_part2 = (4, 5, 6)
tuple_combine = tuple_part1 + tuple_part2
print(tuple_combine)


# Challenge 7: Repeating Tuples
# Goal: Create a new tuple by repeating an existing tuple multiple times.
# Steps:
# Create a tuple named pattern with the elements ('A', 'B').
# Repeat the pattern tuple 4 times to create a new tuple named repeated_pattern.
# Print repeated_pattern.
pattern = ('A', 'B')
repeated_pattern = pattern * 4
print(repeated_pattern)


# Challenge 8: Slicing Tuples - Basic
# Goal: Extract a portion of a tuple using slicing.
# Steps:
# Create a tuple named alphabet containing the first 7 letters of 
# the alphabet (e.g., ('a', 'b', 'c', 'd', 'e', 'f', 'g')).
# Slice alphabet to get the middle three letters (e.g., 'c', 'd', 'e') 
# and store them in a new tuple called middle_letters.
# Print middle_letters.
alphabet = ('a', 'b', 'c', 'd', 'e', 'f', 'g')
middle_letters = alphabet[2:5]
print(middle_letters)


# Challenge 9: Slicing Tuples - Reversing
# Goal: Reverse the order of elements in a tuple using slicing.
# Steps:
# Use the alphabet tuple from Challenge 8.
# Reverse the alphabet tuple and store the result in a 
# new tuple called reversed_alphabet.
# Print reversed_alphabet.
alphabet = ('a', 'b', 'c', 'd', 'e', 'f', 'g')
reversed_alphabet = alphabet[::-1]
print(reversed_alphabet)


# Challenge 10: Counting Elements
# Goal: Count the occurrences of a specific element within a tuple.
# Steps:
# Create a tuple named data_points with various numbers, 
# including some duplicates (e.g., (10, 20, 30, 20, 40, 20, 50)).
# Count how many times the number 20 appears in data_points.
# Print the count.
data_points = (10, 20, 30, 20, 40, 20, 50)
print(data_points.count(20))


# Challenge 11: Iterating Through Tuples
# Goal: Use a for loop to process each element in a tuple.
# Steps:
# Create a tuple named colors with a few color names 
# (e.g., ('red', 'green', 'blue')).
# Use a for loop to iterate through the colors tuple.
# Inside the loop, print each color on a new line, perhaps with a 
# friendly message like "My favorite color is: [color]".
colors = ('red', 'green', 'blue')
for fav in colors:
    print(f'My fav color is {fav}')


# Challenge 12: Sorting Tuples (Resulting in a List)
# Goal: Understand how to sort a tuple and what data type the result will be.
# Steps:
# Create a tuple named unsorted_numbers with a few
#  numbers in a random order (e.g., (8, 2, 5, 1, 9)).
# Use the sorted() function to sort unsorted_numbers and 
# store the result in a variable named sorted_list.
# Print sorted_list and observe its data type (you can use 
# type(sorted_list) to confirm).
unsorted_numbers = (8, 2, 5, 1, 9)
sorted_list = sorted(unsorted_numbers)
print(sorted_list, type(sorted_list))

# Challenge 13: Nested Tuples - Accessing Elements
# Goal: Access elements within a nested tuple.
# Steps:
# Create a nested tuple named student_grades where each 
# inner tuple represents a student's name and their 
# score (e.g., (("Alice", 95), ("Bob", 88), ("Charlie", 72))).
# Access and print Bob's score.
# Access and print Alice's name.
nested_tuple = (
    ("Alice", 95),
    ("Bob", 88),
    ("Charlie", 72)
)
print(nested_tuple[1][1])
print(nested_tuple[0][0])


# Challenge 14: Checking for Membership
# Goal: Determine if a specific value or a nested tuple exists within a tuple.
# Steps:
# Use the student_grades tuple from Challenge 13.
# Check if the tuple ("Bob", 88) is present in student_grades and print a
#  message indicating if it's "found" or "not found".
# Check if the name "David" is present within any of the inner tuples 
# (this will require a slightly different approach or loop, 
# but keep it simple for now and just check directly if a specific full 
# student tuple exists).
nested_tuple = (
    ("Alice", 95),
    ("Bob", 88),
    ("Charlie", 72)
)
if ('Bob', 88) in nested_tuple:
    print('Found')
else:
    print('Not Foound')

if ('David', ) in nested_tuple:
    print('Found')
else:
    print('Not Foound')


# # Challenge 15: Immutability Concept
# # Goal: Demonstrate the immutability of tuples by attempting to modify one.
# # Steps:
# # Create a tuple named my_immutable_tuple with a few elements (e.g., (10, 20, 30)).
# # Try to change the value of the first element (e.g., my_immutable_tuple[0] = 5).
# # Observe the error message you receive. This visually confirms that 
# # tuples are immutable. You don't need to fix the error, 
# # just understand why it occurs.
# my_immutable_tuple = (10, 20, 30)
# my_immutable_tuple[0] = 5
# print(my_immutable_tuple)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 10
#       1 # Challenge 15: Immutability Concept
#       2 # Goal: Demonstrate the immutability of tuples by attempting to modify one.
#       3 # Steps:
#    (...)      7 # tuples are immutable. You don't need to fix the error,
#       8 # just understand why it occurs.
#       9 my_immutable_tuple = (10, 20, 30)
# ---> 10 my_immutable_tuple[0] = 5
#      11 print(my_immutable_tuple)
#
# TypeError: 'tuple' object does not support item assignment
