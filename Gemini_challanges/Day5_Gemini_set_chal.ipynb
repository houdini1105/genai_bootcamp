# %%
# Challenge 1: Finding Unique Words
# Concept: Sets are excellent for identifying unique items from a collection.
# Scenario: You have a sentence and you want to find out how many 
# unique words it contains. The words should be treated as case-insensitive.
# Challenge: Create a Python script that takes a string of words, 
# converts it to a set of unique words (ignoring case), 
# and prints the number of unique words found.
# Walk-through Steps:
# Define the initial string: Start with a variable holding a sentence.
# Split the string: Break the sentence into a list of individual words.
# Convert to a set: Use a set to automatically handle the uniqueness of the words. 
# You'll need to consider how to handle the case-insensitivity requirement before or during this step.
# Count the unique words: Find a way to get the total count of elements in the resulting set.
# Print the result: Display the final count.
sent = input('ENter a sent').lower()
split_sent = sent.split()
new_set = set(split_sent)
print(len(new_set), new_set)

# Challenge 2: Merging Two Collections
# Concept: Sets can be easily combined to form a new set with 
# unique elements from both.
# Scenario: You have two different collections of user IDs from 
# two separate systems and you want to combine them into a single list of
#  unique IDs.
# Challenge: Create two sets, system1_ids = {101, 102, 103} and 
# system2_ids = {103, 104, 105}. Combine them into a new set named all_ids 
# and print the result. The final set should contain all unique IDs 
# from both systems.
# Walk-through Steps:
# Initialize the two sets: Define two separate variables for the user IDs.
# Combine the sets: Find a method or operator that combines the 
# elements of two sets into a new one, ensuring there are no duplicates.
# Print the final set: Display the combined set.
system1_ids = {101, 102, 103}
system2_ids = {103, 104, 105}
test = system1_ids
all_ids = system1_ids | system2_ids
print(all_ids)


# Challenge 3: Set and Dictionary Confusion
# Concept: Distinguishing between an empty set and an empty dictionary 
# based on their creation syntax.
# Scenario: You've been asked to create a variable that will eventually 
# hold a set of data, but you need to initialize it as empty first.
# Challenge: Create a variable named my_collection and initialize it as an empty set. 
# Then, print its data type using the type() function to confirm it is a 
# set and not a dictionary.
# Walk-through Steps:
# Choose the correct syntax: Think about the specific syntax for creating 
# an empty set.
# Assign the variable: Create a variable and assign the empty set to it.
# Check the type: Use the type() function to check the variable's data type.
# Print the result: Display the output of the type() function.
my_dictionary = set()
my_dictionary1 = {}
print(type(my_dictionary), type(my_dictionary1))


# Challenge 4: Handling Errors When Removing Elements
# Concept: The .remove() method raises an error if the specified element is
#  not found in the set. You should be prepared to handle this gracefully.
# Scenario: You need to remove a student from a class list, but you are not 
# sure if that student is on the list to begin with.
# Challenge: Create a set class_list = {'Anna', 'Ben', 'Chris'}. Attempt to 
# remove the student 'David' and observe the error. Then, research a 
# different set method that performs a similar removal but does not raise 
# an error if the element is missing. Modify your code to use that 
# method instead.
# Walk-through Steps:
# Initialize the set: Define the class_list with the specified names.
# Attempt the initial removal: Write the line of code to remove 'David'.
# Observe the error: Run the code and note the error message.
# Find an alternative method: Research Python set methods for removing elements 
# that are "safe" from errors.
# Use the alternative method: Rewrite the removal line using the new method.
# Print the set: Display the final set to show no changes occurred.
class_list = {'Anna', 'Ben', 'Chris'}
#error = class_list.remove('David')
updated_class_list = class_list.discard('David')
print(class_list)


# Challenge 5: Sets of Tuples
# Concept: Sets can contain elements of various immutable types, 
# including tuples.
# Scenario: You're tracking the coordinates of objects in a 2D space. 
# Each coordinate pair is a (x, y) tuple, and you need a collection of 
# unique coordinate pairs.
# Challenge: Create a set named unique_points containing the 
# following coordinate tuples: (1, 2), (2, 3), (1, 2), and (3, 4). 
# Print the final set to confirm that the duplicate tuple has been 
# automatically removed.
# Walk-through Steps:
# Define the data: Create the set with the given tuples as elements.
# Confirm the contents: Print the set.
# Explain the result: Consider why the output set only contains three 
# elements instead of four.
unique_points = (1, 2), (2, 3), (1, 2), (3, 4)
unique_points_set = set(unique_points)
print(unique_points_set)


# Challenge 6: Creating a frozenset
# Concept: Understanding the correct syntax for creating an immutable set.
# Scenario: You need to define a set of constant values that 
# should never be changed or modified in your program.
# Challenge: Create a frozenset named vowels containing the 
# elements 'a', 'e', 'i', 'o', 'u'. Print its type to verify that it 
# is a frozenset.
# Walk-through Steps:
# Choose the correct constructor: Use the frozenset() constructor to 
# create the set.
# Pass the elements: Provide the elements inside the parentheses.
# Check the type: Use the type() function to confirm the variable's data type.
# Print the result: Display the output of the type() function.
vowels = ('a', 'e', 'i', 'o', 'u')
vowel_froz_set = frozenset(vowels)
print(type(vowel_froz_set))


# Challenge 7: Iterating and Conditional Printing
# Concept: Combining set iteration with conditional logic (if statements).
# Scenario: You have a set of student scores and you want to print out 
# only the scores that are above a certain threshold.
# Challenge: Create a set named scores = {85, 92, 78, 65, 95}. 
# Loop through the set and print only the scores that are greater than or 
# equal to 90.
# Walk-through Steps:
# Initialize the set: Create the scores set with the given values.
# Create a for loop: Write a for loop to iterate over each score in the set.
# Add a condition: Inside the loop, use an if statement to check if the 
# current score meets the threshold.
# Print conditionally: If the condition is met, print the score.
scores = {85, 92, 78, 65, 95}
for n in scores:
    if n > 80:
        print(n)


# Challenge 8: Converting a List with Duplicates
# Concept: Using the set() constructor to convert a list and remove duplicates.
# Scenario: You have a list of items a user has clicked on, and you 
# need to generate a list of unique items for an analytics report.
# Challenge: Take the list 
# clicked_items = ['image', 'video', 'ad', 'image', 'video', 'image']. 
# Convert it to a set to remove duplicates, then convert the set back 
# to a list and print the result. The final list should contain 
# only unique items.
# Walk-through Steps:
# Define the initial list: Create a variable holding the list of clicked items.
# Convert to a set: Use the set() constructor to create a set from the list. 
# This will automatically remove duplicates.
# Convert back to a list: Use the list() constructor to convert the unique 
# set back into a list.
# Print the final list: Display the result.
clicked_items = ['image', 'video', 'ad', 'image', 'video', 'image']
clicked_items_set = set(clicked_items)
final_click_items = list(clicked_items_set)
print(type(final_click_items), final_click_items)


# Challenge 9: Checking for Unordered Equality
# Concept: Understanding that sets are unordered, so their equality 
# check doesn't depend on element position, unlike lists.
# Scenario: You have two collections of student names and you want to check 
# if they contain the exact same students, regardless of the order in which
#  the names were listed.
# Challenge: Create two sets, class_a = {'Tom', 'Sue', 'Jack'} and
#  class_b = {'Jack', 'Sue', 'Tom'}. Write a Python script to check 
# if class_a is equal to class_b and print True or False.
# Walk-through Steps:
# Initialize the two sets: Define both class_a and class_b.
# Use the equality operator: Use the == operator to compare the two sets.
# Print the result: Display the boolean result of the comparison.
class_a = {'Tom', 'Sue', 'Jack'}
class_b = {'Jack', 'Sue', 'Tom'}
same = class_a == class_b
print(same)


# Challenge 10: Using in and not in
# Concept: Using membership operators to check for the presence or absence 
# of an element.
# Scenario: You have a set of valid user roles, and you need to write a
#  simple check to see if a given role is valid or not.
# Challenge: Create a set valid_roles = {'admin', 'editor', 'viewer'}. 
# Check if the role 'admin' is present in the set and print "Role is valid". 
# Then, check if the role 'guest' is not in the set and print "Role is invalid".
# Walk-through Steps:
# Initialize the set: Define the valid_roles set.
# Write the first check: Use the in operator inside an if statement to check 
# for the presence of 'admin'.
# Print the first message: Print the success message inside the if block.
# Write the second check: Use the not in operator inside another if statement
#  to check for the absence of 'guest'.
# Print the second message: Print the failure message inside this if block.
valid_roles = {'admin', 'editor', 'viewer'}
if 'admin' in valid_roles:
    print('Success')
if 'guest' not in valid_roles:
    print('Failure')

# %%
# Out:
# Success
# Failure
